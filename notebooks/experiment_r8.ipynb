# %% [markdown]
# <a href="https://colab.research.google.com/github/albert-yue/gcn-explainability/blob/master/notebooks/6864_final_project_r8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My\ Drive/MIT/gcn_explainability/
# Out:
# /content/gdrive/My Drive/MIT/gcn_explainability

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/albert-yue/gcn-explanability
#    f12580f..b9a08fa  master     -> origin/master
# Updating f12580f..b9a08fa
# Fast-forward
#  notebooks/experiment_20ng.ipynb | 5510 +++++++++++++++++++++++++++++++++++++++
#  1 file changed, 5510 insertions(+)
#  create mode 100644 notebooks/experiment_20ng.ipynb

# %% [markdown]
# # Set up Vocabulary and Labels

# %%
from src.data import save_all_labels

save_all_labels('data/r8-labels.txt', 'data/train-r8.txt', 'data/test-r8.txt')

# %%
from tqdm.auto import tqdm

def save_vocabulary(out_path, train_path, test_path, doc_freq_threshold=5):
    word_freqs = {}  # counting num of docs
    for data_path in [train_path, test_path]:
        with open(data_path, 'r') as f:
            for line in tqdm(f.readlines()):
                line = line.strip()
                _, text = line.split('\t')
                words = text.split()
                for w in set(words):
                    w = w.strip()
                    if w in word_freqs: word_freqs[w] += 1
                    else: word_freqs[w] = 1
    vocab = []
    for w, freq in word_freqs.items():
        if freq >= doc_freq_threshold:
            vocab.append(w)
    with open(out_path, 'w+') as f:
        f.write('\n'.join(vocab))

# %%
save_vocabulary('data/r8-vocabulary.txt', 'data/train-r8.txt', 'data/test-r8.txt')
# Out:
# HBox(children=(IntProgress(value=0, max=5485), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2189), HTML(value='')))

# %% [markdown]
# # Training

# %%
from src.data import Corpus, get_data, get_vocabulary, get_labels
from src.models.gcn import GCN
from src.preprocessing import clean_text, build_adj_matrix, normalize_adj
from src.train import train, evaluate, accuracy

# %%
seed = 0
val_split = 0.1

vocab = get_vocabulary('data/r8-vocabulary.txt')
labels = get_labels('data/r8-labels.txt')
corpus = get_data('data/train-r8.txt', labels)
test_corpus = get_data('data/test-r8.txt', labels)

# Split validation set
corpus.shuffle(seed)
len_train = int(len(corpus) * (1 - val_split))
train_corpus = Corpus(corpus[:len_train])
val_corpus = Corpus(corpus[len_train:])

num_documents = len(train_corpus) + len(val_corpus) + len(test_corpus)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Mask out unknown words
clean_text(corpus, vocab)
clean_text(test_corpus, vocab)
# Out:
# HBox(children=(IntProgress(value=0, max=5485), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2189), HTML(value='')))

# %%
train_adj_matrix = build_adj_matrix(train_corpus, vocab, num_documents, doc_offset=0)
val_adj_matrix = build_adj_matrix(val_corpus, vocab, num_documents, doc_offset=len(train_corpus))
test_adj_matrix = build_adj_matrix(test_corpus, vocab, num_documents, doc_offset=len(train_corpus) + len(val_corpus))
# Out:
# Building word frequencies per doc
# HBox(children=(IntProgress(value=0, max=4936), HTML(value='')))
# Building word frequencies per window
# HBox(children=(IntProgress(value=0, max=4936), HTML(value='')))
# Calculating PMIs
# HBox(children=(IntProgress(value=0, max=1279723), HTML(value='')))
# Calculating TF-IDF
# HBox(children=(IntProgress(value=0, max=6191), HTML(value='')))
# Identities
# HBox(children=(IntProgress(value=0, max=13865), HTML(value='')))
# Building word frequencies per doc
# HBox(children=(IntProgress(value=0, max=549), HTML(value='')))
# Building word frequencies per window
# HBox(children=(IntProgress(value=0, max=549), HTML(value='')))
# Calculating PMIs
# HBox(children=(IntProgress(value=0, max=227102), HTML(value='')))
# Calculating TF-IDF
# HBox(children=(IntProgress(value=0, max=6191), HTML(value='')))
# Identities
# HBox(children=(IntProgress(value=0, max=13865), HTML(value='')))
# Building word frequencies per doc
# HBox(children=(IntProgress(value=0, max=2189), HTML(value='')))
# Building word frequencies per window
# HBox(children=(IntProgress(value=0, max=2189), HTML(value='')))
# Calculating PMIs
# HBox(children=(IntProgress(value=0, max=622022), HTML(value='')))
# Calculating TF-IDF
# HBox(children=(IntProgress(value=0, max=6191), HTML(value='')))
# Identities
# HBox(children=(IntProgress(value=0, max=13865), HTML(value='')))

# %%
from src.utils import save_sparse_tensor

save_sparse_tensor(train_adj_matrix, 'data/20ng_train_adj_matrix.pt')
save_sparse_tensor(val_adj_matrix, 'data/20ng_val_adj_matrix.pt')
save_sparse_tensor(test_adj_matrix, 'data/20ng_test_adj_matrix.pt')

# %%
from src.utils import load_sparse_tensor

train_adj_matrix = load_sparse_tensor('data/20ng_train_adj_matrix.pt')
val_adj_matrix = load_sparse_tensor('data/20ng_val_adj_matrix.pt')
test_adj_matrix = load_sparse_tensor('data/20ng_test_adj_matrix.pt')

# %%
train_adj_matrix = normalize_adj(train_adj_matrix)
val_adj_matrix = normalize_adj(val_adj_matrix)
test_adj_matrix = normalize_adj(test_adj_matrix)

# %%
hidden_size = 200  # hyperparameter
dropout = 0.5  # hyperparameter
epochs = 500

num_vertices = len(vocab) + num_documents
model = GCN(num_vertices, hidden_size, len(labels), dropout=dropout)

# %%
# %time train_losses, val_losses = train(model, train_adj_matrix, val_adj_matrix, train_corpus.labels(), val_corpus.labels(), len(vocab), epochs=epochs, plot_every=5, print_every=10, save_path='logs.pt')
# Out:
# Epoch 0
# Train mean cross-entropy: 2.080047845840454
# Validation mean cross-entropy: 2.0769033432006836
# Epoch 10
# Train mean cross-entropy: 2.0157127380371094
# Validation mean cross-entropy: 2.0267844200134277
# Epoch 20
# Train mean cross-entropy: 1.9329428672790527
# Validation mean cross-entropy: 1.9647645950317383
# Epoch 30
# Train mean cross-entropy: 1.8366948366165161
# Validation mean cross-entropy: 1.8915430307388306
# Epoch 40
# Train mean cross-entropy: 1.7302392721176147
# Validation mean cross-entropy: 1.811198353767395
# Epoch 50
# Train mean cross-entropy: 1.6093989610671997
# Validation mean cross-entropy: 1.7310272455215454
# Epoch 60
# Train mean cross-entropy: 1.4883463382720947
# Validation mean cross-entropy: 1.657422423362732
# Epoch 70
# Train mean cross-entropy: 1.3789948225021362
# Validation mean cross-entropy: 1.5922960042953491
# Epoch 80
# Train mean cross-entropy: 1.2674394845962524
# Validation mean cross-entropy: 1.533158302307129
# Epoch 90
# Train mean cross-entropy: 1.1574900150299072
# Validation mean cross-entropy: 1.4763027429580688
# Epoch 100
# Train mean cross-entropy: 1.0808454751968384
# Validation mean cross-entropy: 1.422211766242981
# Epoch 110
# Train mean cross-entropy: 1.002159595489502
# Validation mean cross-entropy: 1.3702049255371094
# Epoch 120
# Train mean cross-entropy: 0.9159160852432251
# Validation mean cross-entropy: 1.3224413394927979
# Epoch 130
# Train mean cross-entropy: 0.8502737283706665
# Validation mean cross-entropy: 1.2802066802978516
# Epoch 140
# Train mean cross-entropy: 0.8027889728546143
# Validation mean cross-entropy: 1.2395983934402466
# Epoch 150
# Train mean cross-entropy: 0.7474486231803894
# Validation mean cross-entropy: 1.2020066976547241
# Epoch 160
# Train mean cross-entropy: 0.6997609734535217
# Validation mean cross-entropy: 1.1677838563919067
# Epoch 170
# Train mean cross-entropy: 0.6643438339233398
# Validation mean cross-entropy: 1.136102557182312
# Epoch 180
# Train mean cross-entropy: 0.6247974634170532
# Validation mean cross-entropy: 1.1059547662734985
# Epoch 190
# Train mean cross-entropy: 0.5886519551277161
# Validation mean cross-entropy: 1.0786867141723633
# Epoch 200
# Train mean cross-entropy: 0.5514562129974365
# Validation mean cross-entropy: 1.0517079830169678
# Epoch 210
# Train mean cross-entropy: 0.5322631001472473
# Validation mean cross-entropy: 1.0256373882293701
# Epoch 220
# Train mean cross-entropy: 0.5091214179992676
# Validation mean cross-entropy: 0.9991351962089539
# Epoch 230
# Train mean cross-entropy: 0.49022066593170166
# Validation mean cross-entropy: 0.9752275943756104
# Epoch 240
# Train mean cross-entropy: 0.46320614218711853
# Validation mean cross-entropy: 0.9526180624961853
# Epoch 250
# Train mean cross-entropy: 0.4406578540802002
# Validation mean cross-entropy: 0.9322521090507507
# Epoch 260
# Train mean cross-entropy: 0.4239674508571625
# Validation mean cross-entropy: 0.9148330688476562
# Epoch 270
# Train mean cross-entropy: 0.40800419449806213
# Validation mean cross-entropy: 0.8948614001274109
# Epoch 280
# Train mean cross-entropy: 0.3941892981529236
# Validation mean cross-entropy: 0.871557354927063
# Epoch 290
# Train mean cross-entropy: 0.37711694836616516
# Validation mean cross-entropy: 0.853084921836853
# Epoch 300
# Train mean cross-entropy: 0.362606018781662
# Validation mean cross-entropy: 0.838324248790741
# Epoch 310
# Train mean cross-entropy: 0.3444627523422241
# Validation mean cross-entropy: 0.821066677570343
# Epoch 320
# Train mean cross-entropy: 0.3342835307121277
# Validation mean cross-entropy: 0.8050674796104431
# Epoch 330
# Train mean cross-entropy: 0.3232365846633911
# Validation mean cross-entropy: 0.7908376455307007
# Epoch 340
# Train mean cross-entropy: 0.310379296541214
# Validation mean cross-entropy: 0.7766931653022766
# Epoch 350
# Train mean cross-entropy: 0.2905854284763336
# Validation mean cross-entropy: 0.7633754014968872
# Epoch 360
# Train mean cross-entropy: 0.2877238690853119
# Validation mean cross-entropy: 0.7459130883216858
# Epoch 370
# Train mean cross-entropy: 0.27860450744628906
# Validation mean cross-entropy: 0.7337965965270996
# Epoch 380
# Train mean cross-entropy: 0.2683960199356079
# Validation mean cross-entropy: 0.7241231799125671
# Epoch 390
# Train mean cross-entropy: 0.25862917304039
# Validation mean cross-entropy: 0.7088615894317627
# Epoch 400
# Train mean cross-entropy: 0.248191699385643
# Validation mean cross-entropy: 0.697192907333374
# Epoch 410
# Train mean cross-entropy: 0.24091246724128723
# Validation mean cross-entropy: 0.6870861649513245
# Epoch 420
# Train mean cross-entropy: 0.23226137459278107
# Validation mean cross-entropy: 0.6751352548599243
# Epoch 430
# Train mean cross-entropy: 0.22828105092048645
# Validation mean cross-entropy: 0.6682208180427551
# Epoch 440
# Train mean cross-entropy: 0.21691080927848816
# Validation mean cross-entropy: 0.657978355884552
# Epoch 450
# Train mean cross-entropy: 0.21771296858787537
# Validation mean cross-entropy: 0.6449607610702515
# Epoch 460
# Train mean cross-entropy: 0.20498348772525787
# Validation mean cross-entropy: 0.6391665935516357
# Epoch 470
# Train mean cross-entropy: 0.2023029625415802
# Validation mean cross-entropy: 0.6348205208778381
# Epoch 480
# Train mean cross-entropy: 0.1983993500471115
# Validation mean cross-entropy: 0.6254851222038269
# Epoch 490
# Train mean cross-entropy: 0.19156788289546967
# Validation mean cross-entropy: 0.6121693253517151
# CPU times: user 7min 18s, sys: 5.13 s, total: 7min 23s
# Wall time: 7min 41s

# %%
from matplotlib import pyplot as plt

def plot_loss(train_losses, val_losses):
    plt.title("R8 Loss per Epoch")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.plot(train_losses, label='train')
    plt.plot(val_losses, label='val')
    plt.legend(loc='lower left')

# %%
plot_loss(train_losses, val_losses)

# %%
test_start_idx = len(vocab) + len(train_corpus) + len(val_corpus)
test_loss = evaluate(model, test_adj_matrix, test_corpus.labels(), accuracy, start_idx=test_start_idx)
print(test_loss)
# Out:
# 0.7121973503883051
